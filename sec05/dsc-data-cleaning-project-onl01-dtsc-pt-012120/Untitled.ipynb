# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
heroes_df = pd.read_csv('heroes_information.csv')
powers_df = pd.read_csv('super_hero_powers.csv')

heroes_df.head()
heroes_df.shape
# Out:
# (734, 11)

# %%
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
powers_df.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
# ...

# %%
heroes_df = heroes_df.drop('Unnamed: 0', axis=1)

# %%
heroes_df.head(2)
# Out:
#          name Gender Eye color           Race Hair color  Height  \
# 0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0

# %%
heroes_df.info
# Out:
# <bound method DataFrame.info of                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
# ...

# %%
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
# name          734 non-null object
# Gender        734 non-null object
# Eye color     734 non-null object
# Race          734 non-null object
# Hair color    734 non-null object
# Height        734 non-null float64
# Publisher     719 non-null object
# Skin color    734 non-null object
# Alignment     734 non-null object
# Weight        732 non-null float64
# dtypes: float64(2), object(8)
# memory usage: 57.5+ KB

# %%
powers_df.info
# Out:
# <bound method DataFrame.info of           hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0            3-D Man     True                False               False
# 1             A-Bomb    False                 True               False
# 2         Abe Sapien     True                 True               False
# 3           Abin Sur    False                False                True
# 4        Abomination    False                 True               False
# ..               ...      ...                  ...                 ...
# 662  Yellowjacket II    False                False               False
# 663             Ymir    False                False               False
# 664             Yoda     True                False               False
# 665          Zatanna    False                False               False
# 666             Zoom    False                False               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# ...

# %%
powers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 168 entries, hero_names to Omniscient
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB

# %%
powers_df.shape
# Out:
# (667, 168)

# %%
heroes_df.shape
# Out:
# (734, 10)

# %%
heroes_df.isna().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
heroes_df.describe()
# Out:
#            Height      Weight
# count  734.000000  732.000000
# mean   102.254087   43.855191
# std    139.624543  130.823733
# min    -99.000000  -99.000000
# 25%    -99.000000  -99.000000
# 50%    175.000000   62.000000
# 75%    185.000000   90.000000
# max    975.000000  900.000000

# %%
heroes_df.dtypes
# Out:
# name           object
# Gender         object
# Eye color      object
# Race           object
# Hair color     object
# Height        float64
# Publisher      object
# Skin color     object
# Alignment      object
# Weight        float64
# dtype: object

# %%
mean_weight = heroes_df['Weight'].mean()
heroes_df['Weight'].fillna(mean_weight, inplace=True)
heroes_df.isna().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         0
# dtype: int64

# %%
heroes_df.columns
# Out:
# Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height',
#        'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %%
powers_df.columns
# Out:
# Index(['hero_names', 'Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=168)

# %%
powers_df.isna().any().any()
# Out:
# False

# %%
heroes_df.isna().any().any()
# Out:
# True

# %%
heroes_df.drop_duplicates(subset='name', inplace=True)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %%
heroes_df.reset_index(drop=True, inplace=True)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %%
powers_df.rename(columns={'hero_names': 'name'}, inplace=True)

# %%
hp_df = powers_df.set_index('name').join(heroes_df.set_index('name'), how='left')

# %%
hp_df = heroes_df.set_index('name').join(powers_df.set_index('name'), how='left')
heroes_and_powers_df_left = powers_df.set_index('name').join(heroes_df.set_index('name'), how='left')
heroes_and_powers_df_left.head()
# Out:
#              Agility  Accelerated Healing  Lantern Power Ring  \
# name
# 3-D Man         True                False               False
# A-Bomb         False                 True               False
# Abe Sapien      True                 True               False
# Abin Sur       False                False                True
# Abomination    False                 True               False
#
#              Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# name
# 3-D Man                      False            False       False    False
# A-Bomb                       False            False        True    False
# Abe Sapien                   False             True        True    False
# Abin Sur                     False            False       False    False
# Abomination                  False            False       False    False
#
#              Energy Absorption  Flight  Danger Sense  ...  Omniscient  Gender  \
# ...

# %%
hp_df.head()
# Out:
#              Agility  Accelerated Healing  Lantern Power Ring  \
# name
# 3-D Man         True                False               False
# A-Bomb         False                 True               False
# Abe Sapien      True                 True               False
# Abin Sur       False                False                True
# Abomination    False                 True               False
#
#              Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# name
# 3-D Man                      False            False       False    False
# A-Bomb                       False            False        True    False
# Abe Sapien                   False             True        True    False
# Abin Sur                     False            False       False    False
# Abomination                  False            False       False    False
#
#              Energy Absorption  Flight  Danger Sense  ...  Omniscient  Gender  \
# ...

# %%
male_heroes_df = hp_df[hp_df['Gender'] == 'Male']
female_heroes_df = hp_df[hp_df['Gender'] == 'Female']

# %%
female_heroes_df.head()
# Out:
#                  Agility  Accelerated Healing  Lantern Power Ring  \
# name
# Angel Dust          True                False               False
# Angel Salvadore    False                False               False
# Angela             False                False               False
# Arachne             True                 True               False
# Arclight           False                False               False
#
#                  Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# name
# Angel Dust                       False            False       False    False
# Angel Salvadore                  False            False       False    False
# Angela                           False            False       False    False
# Arachne                          False            False        True    False
# Arclight                         False            False        True    False
#
#                  Energy Absorption  Flight  Danger Sense  ...  Omniscient  \
# ...

# %%
female_heroes_df.loc[female_heroes_df['Super Strength'] == 'True']
# Out:
# /Users/badmin/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Empty DataFrame
# ...

# %%
ss_df = hp_df[['Super Strength', 'Gender']]

# %%
ss_df = ss_df[ss_df['Super Strength']==True]

# %%
ss_df.head()
# Out:
#             Super Strength Gender
# name
# 3-D Man               True    NaN
# A-Bomb                True   Male
# Abe Sapien            True   Male
# Abomination           True   Male
# Abraxas               True   Male

# %%
ss_f = ss_df[ss_df['Gender']== 'Female']

# %%
ss_f.head()
# Out:
#            Super Strength  Gender
# name
# Angel Dust           True  Female
# Arachne              True  Female
# Arclight             True  Female
# Ardina               True  Female
# Armor                True  Female

# %%
ss_df.describe()
# Out:
#        Super Strength Gender
# count             684    660
# unique              2      3
# top              True   Male
# freq              372    464

# %%
ss_df.values
# Out:
# array([[True, nan],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Female'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Female'],
#        [True, 'Male'],
#        [True, 'Female'],
#        [True, 'Female'],
#        [True, 'Male'],
#        [True, 'Female'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, 'Male'],
#        [True, nan],
# ...

# %%
ss_df.count
# Out:
# <bound method DataFrame.count of                  Super Strength  Gender
# name
# 3-D Man                    True     NaN
# A-Bomb                     True    Male
# Abe Sapien                 True    Male
# Abin Sur                  False    Male
# Abomination                True    Male
# ...                         ...     ...
# Yellowjacket II           False  Female
# Ymir                       True    Male
# Yoda                      False    Male
# Zatanna                   False  Female
# Zoom                      False    Male
#
# [684 rows x 2 columns]>

# %%
ss_df.loc['Gender'] == 'Female'
# Out:
# Super Strength    True
# Gender            True
# Name: Gender, dtype: bool

# %%
ss_df.loc[ss_df['Gender'] == 'Female'], (ss_df['Super Strength'] == 'True')
# Out:
# (                Super Strength  Gender
#  name
#  Angel Dust                True  Female
#  Angel Salvadore          False  Female
#  Angela                   False  Female
#  Arachne                   True  Female
#  Arclight                  True  Female
#  ...                        ...     ...
#  Wonder Woman              True  Female
#  X-23                      True  Female
#  Yellowjacket II          False  Female
#  Zatanna                  False  Female
#  Gender                  Female  Female
#
#  [179 rows x 2 columns], name
#  3-D Man        False
#  A-Bomb         False
#  Abe Sapien     False
#  Abin Sur       False
#  Abomination    False
#                 ...
#  Ymir           False
#  Yoda           False
#  Zatanna        False
#  Zoom           False
#  Gender         False
#  Name: Super Strength, Length: 685, dtype: bool)

# %%
fss_df = female_heroes_df[["Super Strength"] ==True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-835e1e9e7801> in <module>
# ...
